# %% [markdown]
# ### Model Performance Overview
#
# | Model | Accuracy | ROC AUC | Optimal Profit Π* | ΔΠ (vs baseline) |
# |:---------------------------------|:---------:|:--------:|:----------------:|:----------------:|
# | **Baseline (A0)** | **0.554** | **0.571** | **66 260** | — |
# | **Extended model (A1)** | **0.579** | **0.624** | **72 967** | **+6 707** |
